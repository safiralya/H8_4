# %% [markdown]
# * Nama : Safira Alya Fafaza
# * Student-ID : PYTN-KS14-017

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Bank Additional Full

# %%
df_bank_add_full = pd.read_csv("bank-additional-full.csv", sep=";")
df_bank_add_full
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ## Bank Full

# %%
df_bank_full = pd.read_csv("bank-full.csv", sep=";")
df_bank_full
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Bank Additional Full

# %%
df_bank_add_full
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ### Jumlah Data

# %%
df_bank_add_full.shape
# Out:
# (41188, 21)

# %% [markdown]
# ### Informasi Data

# %%
df_bank_add_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
# ...

# %% [markdown]
# **bank client data**
# * age (numeric)
# * job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# * marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# * education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# * default: has credit in default? (categorical: 'no','yes','unknown')
# * housing: has housing loan? (categorical: 'no','yes','unknown')
# * loan: has personal loan? (categorical: 'no','yes','unknown')
#
# **related with the last contact of the current campaign**
# * contact: contact communication type (categorical: 'cellular','telephone')
# * month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# * day_of_week: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# * duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# **other attributes**
# * campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# * pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# * previous: number of contacts performed before this campaign and for this client (numeric)
# * poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# **social and economic context attributes**
# * emp.var.rate: employment variation rate - quarterly indicator (numeric)
# * cons.price.idx: consumer price index - monthly indicator (numeric)
# * cons.conf.idx: consumer confidence index - monthly indicator (numeric)
# * euribor3m: euribor 3 month rate - daily indicator (numeric)
# * nr.employed: number of employees - quarterly indicator (numeric)
#
# **output variable (desired target)**
# * 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %% [markdown]
# ### Rangkuman dan Sebaran Data

# %%
df_bank_add_full.describe()
# Out:
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593    962.475454      0.172963
# std       10.42125    259.279249      2.770014    186.910907      0.494901
# min       17.00000      0.000000      1.000000      0.000000      0.000000
# 25%       32.00000    102.000000      1.000000    999.000000      0.000000
# 50%       38.00000    180.000000      2.000000    999.000000      0.000000
# 75%       47.00000    319.000000      3.000000    999.000000      0.000000
# max       98.00000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# ...

# %% [markdown]
# ### Menampilkan 10 Data Teratas

# %%
df_bank_add_full.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %% [markdown]
# ### Menampilkan 10 Data Terbawah

# %%
df_bank_add_full.tail(10)
# Out:
#        age          job   marital            education default housing loan  \
# 41178   62      retired   married    university.degree      no      no   no
# 41179   64      retired  divorced  professional.course      no     yes   no
# 41180   36       admin.   married    university.degree      no      no   no
# 41181   37       admin.   married    university.degree      no     yes   no
# 41182   29   unemployed    single             basic.4y      no     yes   no
# 41183   73      retired   married  professional.course      no     yes   no
# 41184   46  blue-collar   married  professional.course      no      no   no
# 41185   56      retired   married    university.degree      no     yes   no
# 41186   44   technician   married  professional.course      no      no   no
# 41187   74      retired   married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# ...

# %% [markdown]
# ## Bank Full

# %% [markdown]
# ### Jumlah Data

# %%
df_bank_full.shape
# Out:
# (45211, 17)

# %% [markdown]
# ### Informasi Data

# %%
df_bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %% [markdown]
# **bank client data**
# * age (numeric)
# * job : type of job (categorical: 'admin.','blue-collar','entrepreneur','housemaid','management','retired','self-employed','services','student','technician','unemployed','unknown')
# * marital : marital status (categorical: 'divorced','married','single','unknown'; note: 'divorced' means divorced or widowed)
# * education (categorical: 'basic.4y','basic.6y','basic.9y','high.school','illiterate','professional.course','university.degree','unknown')
# * default: has credit in default? (categorical: 'no','yes','unknown')
# * housing: has housing loan? (categorical: 'no','yes','unknown')
# * loan: has personal loan? (categorical: 'no','yes','unknown')
#
# **related with the last contact of the current campaign**
# * contact: contact communication type (categorical: 'cellular','telephone')
# * month: last contact month of year (categorical: 'jan', 'feb', 'mar', ..., 'nov', 'dec')
# * day: last contact day of the week (categorical: 'mon','tue','wed','thu','fri')
# * duration: last contact duration, in seconds (numeric). Important note: this attribute highly affects the output target (e.g., if duration=0 then y='no'). Yet, the duration is not known before a call is performed. Also, after the end of the call y is obviously known. Thus, this input should only be included for benchmark purposes and should be discarded if the intention is to have a realistic predictive model.
#
# **other attributes**
# * campaign: number of contacts performed during this campaign and for this client (numeric, includes last contact)
# * pdays: number of days that passed by after the client was last contacted from a previous campaign (numeric; 999 means client was not previously contacted)
# * previous: number of contacts performed before this campaign and for this client (numeric)
# * poutcome: outcome of the previous marketing campaign (categorical: 'failure','nonexistent','success')
#
# **output variable (desired target)**
# * 21 - y - has the client subscribed a term deposit? (binary: 'yes','no')

# %% [markdown]
# ### Rangkuman dan Sebaran Data

# %%
df_bank_full.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %% [markdown]
# ### Menampilkan 10 Data Teratas

# %%
df_bank_full.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %% [markdown]
# ### Menampilkan 10 Data Terbawah

# %%
df_bank_full.tail(10)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 45201   53    management   married   tertiary      no      583      no   no
# 45202   34        admin.    single  secondary      no      557      no   no
# 45203   23       student    single   tertiary      no      113      no   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %% [markdown]
# # Data Cleansing

# %% [markdown]
# ## Bank Additional Full

# %% [markdown]
# ### Missing Values

# %%
df_bank_add_full.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %% [markdown]
# ### Duplikat

# %%
df_bank_add_full.duplicated().sum()
# Out:
# 12

# %%
df_bank_add_full.drop_duplicates(inplace=True)

# %%
df_bank_add_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Bank Full

# %% [markdown]
# ### Missing Values

# %%
df_bank_full.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %% [markdown]
# ### Duplikat

# %%
df_bank_full.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Bank Additional Full

# %% [markdown]
# ### to Category

# %%
df_bank_add_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  object
#  2   marital         41176 non-null  object
#  3   education       41176 non-null  object
#  4   default         41176 non-null  object
#  5   housing         41176 non-null  object
#  6   loan            41176 non-null  object
#  7   contact         41176 non-null  object
#  8   month           41176 non-null  object
#  9   day_of_week     41176 non-null  object
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  object
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %%
baf_to_category = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day_of_week', 'poutcome']
for column in baf_to_category:
    df_bank_add_full[column] = df_bank_add_full[column].astype('category')
    
df_bank_add_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  category
#  2   marital         41176 non-null  category
#  3   education       41176 non-null  category
#  4   default         41176 non-null  category
#  5   housing         41176 non-null  category
#  6   loan            41176 non-null  category
#  7   contact         41176 non-null  category
#  8   month           41176 non-null  category
#  9   day_of_week     41176 non-null  category
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  category
#  15  emp.var.rate    41176 non-null  float64
# ...

# %% [markdown]
# ### Rename Kolom

# %%
df_bank_add_full = df_bank_add_full.rename(columns={"y":'decision'})
df_bank_add_full
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ### Encoder Bank Additional Full

# %% [markdown]
# Pada saat permodelan hanya dapat menggunakan tipe data objek dalam bentuk int, maka perlu dilakukan pengubahan tipe data menjadi numerical dengan menggunakan encoder.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()

df_category = df_bank_add_full.select_dtypes(include='category')
df_bank_add_full_new = df_bank_add_full.copy()

for column in df_category.columns:
    df_bank_add_full_new[column] = label_encoder.fit_transform(df_bank_add_full_new
                                                               [column])

# %%
df_bank_add_full_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41176 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41176 non-null  int64
#  1   job             41176 non-null  int32
#  2   marital         41176 non-null  int32
#  3   education       41176 non-null  int32
#  4   default         41176 non-null  int32
#  5   housing         41176 non-null  int32
#  6   loan            41176 non-null  int32
#  7   contact         41176 non-null  int32
#  8   month           41176 non-null  int32
#  9   day_of_week     41176 non-null  int32
#  10  duration        41176 non-null  int64
#  11  campaign        41176 non-null  int64
#  12  pdays           41176 non-null  int64
#  13  previous        41176 non-null  int64
#  14  poutcome        41176 non-null  int32
#  15  emp.var.rate    41176 non-null  float64
#  16  cons.price.idx  41176 non-null  float64
# ...

# %% [markdown]
# ## Bank Full

# %% [markdown]
# ### to Category

# %%
df_bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
bf_to_category = ['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'month', 'day', 'poutcome']
for column in bf_to_category:
    df_bank_full[column] = df_bank_full[column].astype('category')
    
df_bank_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  category
#  2   marital    45211 non-null  category
#  3   education  45211 non-null  category
#  4   default    45211 non-null  category
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  category
#  7   loan       45211 non-null  category
#  8   contact    45211 non-null  category
#  9   day        45211 non-null  category
#  10  month      45211 non-null  category
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  category
#  16  y          45211 non-null  object
# dtypes: category(10), int64(6), object(1)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Rename Kolom

# %%
df_bank_full = df_bank_full.rename(columns={"y":'decision'})
df_bank_full
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %% [markdown]
# ### Encoder Bank Full

# %% [markdown]
# Pada saat permodelan hanya dapat menggunakan tipe data objek dalam bentuk int, maka perlu dilakukan pengubahan tipe data menjadi numerical dengan menggunakan encoder.

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
label_encoder = preprocessing.LabelEncoder()

df_category = df_bank_full.select_dtypes(include='category')
df_bank_full_new = df_bank_full.copy()

for column in df_category.columns:
    df_bank_full_new[column] = label_encoder.fit_transform(df_bank_full_new
                                                               [column])

# %%
df_bank_full_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  int32
#  2   marital    45211 non-null  int32
#  3   education  45211 non-null  int32
#  4   default    45211 non-null  int32
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  int32
#  7   loan       45211 non-null  int32
#  8   contact    45211 non-null  int32
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  int32
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  int32
#  16  decision   45211 non-null  object
# dtypes: int32(9), int64(7), object(1)
# memory usage: 4.3+ MB

# %% [markdown]
# # Data Processing

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %% [markdown]
# Menentukan variabel bebas dan variabel terikat :
# * x = variabel bebas = age, job, marital, education, default, housing, loan, contact, month, day_of_week, duration, campaign, pdays, previous, poutcome, emp.var.rate, cons.price.idx, cons.conf.idx, euribor3m, nr.employed
# * y = variabel terikat = decision

# %%
x = df_bank_add_full_new.drop('decision', axis=1)
y = df_bank_add_full_new['decision']

# %% [markdown]
# Membagi data menjadi training dan testing dengan training sebesar 80% dan testing sebesar 20%

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
logReg = LogisticRegression()

# %%
logReg.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
logReg_prediction = logReg.predict(x_test)

# %%
accuracy_logReg = accuracy_score(y_test, logReg_prediction)
print("Berdasarkan Logistic Regression akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_logReg*100)
# Out:
# Berdasarkan Logistic Regression akurasi prediksi klien yang akan berlangganan adalah sebesar :  91.18504128217582

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# %%
matrix_logReg = confusion_matrix(y_test, logReg_prediction)
print(matrix_logReg)
# Out:
# [[7170  177]
#  [ 549  340]]

# %%
cm_logReg = confusion_matrix(y_test, logReg_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Confusion Matrix Logistic Regression")

ax.imshow(cm_logReg)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_logReg[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# ## K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
knn_prediction = knn.predict(x_test)

# %%
accuracy_knn = accuracy_score(y_test, knn_prediction)
print("Berdasarkan K-Nearest Neighbors akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_knn*100)
# Out:
# Berdasarkan K-Nearest Neighbors akurasi prediksi klien yang akan berlangganan adalah sebesar :  90.55366682855755

# %%
matrix_knn = confusion_matrix(y_test, knn_prediction)
print(matrix_knn)
# Out:
# [[7018  329]
#  [ 449  440]]

# %%
cm_knn = confusion_matrix(y_test, knn_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Confusion Matrix K-Nearest Neigbors")

ax.imshow(cm_knn)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_knn[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# ## Support Vector Machine

# %%
a = df_bank_add_full_new.drop('decision', axis=1)
b = df_bank_add_full_new['decision']

# %%
a_train, a_test, b_train, b_test = train_test_split(a,b, test_size=0.2)

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
sv_machine = svm.SVC(kernel='linear')

# %%
sv_machine.fit(a_train, b_train)
# Out:
# SVC(kernel='linear')

# %%
sv_machine_prediction = sv_machine.predict(a_test)

# %%
accuracy_svm = accuracy_score(b_test, sv_machine_prediction)
print("Berdasarkan Support Vector Machine akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_svm*100)
# Out:
# Berdasarkan Support Vector Machine akurasi prediksi klien yang akan berlangganan adalah sebesar :  89.7887323943662

# %%
matrix_svm = confusion_matrix(b_test, sv_machine_prediction)
print(matrix_svm)
# Out:
# [[6940  378]
#  [ 463  455]]

# %%
cm_svm = confusion_matrix(b_test, sv_machine_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Confusion Matrix Support Vector Machine")

ax.imshow(cm_svm)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_svm[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
decTree = DecisionTreeClassifier()

# %%
decTree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
decTree_prediction = decTree.predict(x_test)

# %%
accuracy_decTree = accuracy_score(y_test, decTree_prediction)
print("Berdasarkan Decision Tree akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_decTree*100)
# Out:
# Berdasarkan Decision Tree akurasi prediksi klien yang akan berlangganan adalah sebesar :  89.04808159300632

# %%
matrix_decTree = confusion_matrix(y_test, decTree_prediction)
print(matrix_decTree)
# Out:
# [[6833  514]
#  [ 388  501]]

# %%
cm_decTree = confusion_matrix(y_test, decTree_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Decision Tree Logistic Regression")

ax.imshow(cm_decTree)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_decTree[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
ranForest = RandomForestClassifier(n_estimators=100)

# %%
ranForest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
ranForest_prediction = ranForest.predict(x_test)

# %%
accuracy_ranForest = accuracy_score(y_test, ranForest_prediction)
print("Berdasarkan Random Forest akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_ranForest*100)
# Out:
# Berdasarkan Random Forest akurasi prediksi klien yang akan berlangganan adalah sebesar :  91.68285575522098

# %%
matrix_ranForest = confusion_matrix(y_test, ranForest_prediction)
print(matrix_ranForest)
# Out:
# [[7078  269]
#  [ 416  473]]

# %%
cm_ranForest = confusion_matrix(y_test, ranForest_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Random Forest Logistic Regression")

ax.imshow(cm_ranForest)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_ranForest[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %%
naiveBayes = GaussianNB()

# %%
naiveBayes.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
naiveBayes_prediction = naiveBayes.predict(x_test)

# %%
accuracy_naiveBayes = accuracy_score(y_test, naiveBayes_prediction)
print("Berdasarkan Naive Bayes akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_naiveBayes*100)
# Out:
# Berdasarkan Naive Bayes akurasi prediksi klien yang akan berlangganan adalah sebesar :  84.57989315201554

# %%
matrix_naiveBayes = confusion_matrix(y_test, naiveBayes_prediction)
print(matrix_naiveBayes)
# Out:
# [[6434  913]
#  [ 357  532]]

# %%
cm_naiveBayes = confusion_matrix(y_test, naiveBayes_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Naive Bayes Logistic Regression")

ax.imshow(cm_naiveBayes)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_naiveBayes[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# # Data Visualization

# %%
df_bank_add_full
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %% [markdown]
# ## Presentase Klien yang Berlangganan dan Tidak

# %%
persen_subs_addfull = pd.DataFrame({"Total":df_bank_add_full["decision"].value_counts()})
persen_subs_addfull
# Out:
#      Total
# no   36537
# yes   4639

# %%
explode = (0.1, 0.1)

persen_subs_addfull.plot(kind='pie',
                         figsize=(5, 5),
                         autopct='%1.1f%%',
                         startangle=90,
                         shadow=True,
                         subplots=True,
                         labels=None,
                         pctdistance=1.12,
                         wedgeprops={'edgecolor' : 'black',
                                     'linewidth' : 1,
                                     'antialiased' : True
                                    }
                        )

plt.title('Persentase Klien yang Berlangganan dan Tidak', y=1.12)
plt.axis('equal')
plt.legend(labels=persen_subs_addfull.index, loc='upper left')

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Dapat diketahui bahwa persentase klien yang memutuskan untuk tidak berlangganan lebih besar daripada yang memutuskan berlangganan yaitu sebesar 88.7%

# %% [markdown]
# ## Pinjaman Milik Klien yang Berlangganan

# %%
yes_client_bankfull = df_bank_add_full[(df_bank_add_full['decision'] == 'yes')]
yes_client_bankfull
# Out:
#        age           job   marital            education  default housing loan  \
# 75      41   blue-collar  divorced             basic.4y  unknown     yes   no
# 83      49  entrepreneur   married    university.degree  unknown     yes   no
# 88      49    technician   married             basic.9y       no      no   no
# 129     41    technician   married  professional.course  unknown     yes   no
# 139     45   blue-collar   married             basic.9y  unknown     yes   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 41174   62       retired   married    university.degree       no     yes   no
# 41178   62       retired   married    university.degree       no      no   no
# 41181   37        admin.   married    university.degree       no     yes   no
# 41183   73       retired   married  professional.course       no     yes   no
# 41186   44    technician   married  professional.course       no      no   no
#
# ...

# %%
loan_yes_client_bankfull = pd.DataFrame({"Total":yes_client_bankfull["loan"].value_counts()})
loan_yes_client_bankfull = loan_yes_client_bankfull.sort_values(by='Total')
loan_yes_client_bankfull
# Out:
#          Total
# unknown    107
# yes        683
# no        3849

# %%
loan_yes_client_bankfull.plot(kind='bar', figsize=(10, 6), color='steelblue')

plt.xlabel('loan?')
plt.ylabel('total')
plt.title('Pinjaman Klien yang Memilih Berlangganan')
# Out:
# Text(0.5, 1.0, 'Pinjaman Klien yang Memilih Berlangganan')

# %% [markdown]
# Dapat diketahui bahwa klien yang memutuskan berlangganan kebanyakan tidak memiliki pinjaman.

# %% [markdown]
# ## Pekerjaan Klien yang Memutuskan Berlangganan

# %%
yes_client_bankfull = df_bank_add_full[(df_bank_add_full['decision'] == 'yes')]
yes_client_bankfull
# Out:
#        age           job   marital            education  default housing loan  \
# 75      41   blue-collar  divorced             basic.4y  unknown     yes   no
# 83      49  entrepreneur   married    university.degree  unknown     yes   no
# 88      49    technician   married             basic.9y       no      no   no
# 129     41    technician   married  professional.course  unknown     yes   no
# 139     45   blue-collar   married             basic.9y  unknown     yes   no
# ...    ...           ...       ...                  ...      ...     ...  ...
# 41174   62       retired   married    university.degree       no     yes   no
# 41178   62       retired   married    university.degree       no      no   no
# 41181   37        admin.   married    university.degree       no     yes   no
# 41183   73       retired   married  professional.course       no     yes   no
# 41186   44    technician   married  professional.course       no      no   no
#
# ...

# %%
job_yes_client_bankfull = pd.DataFrame({"Total":yes_client_bankfull["job"].value_counts()})
job_yes_client_bankfull = job_yes_client_bankfull.head(5).sort_values(by='Total', ascending=False)
job_yes_client_bankfull
# Out:
#              Total
# admin.        1351
# technician     730
# blue-collar    638
# retired        434
# management     328

# %%
job_yes_client_bankfull = list(yes_client_bankfull['job'])
job_yes_client_bankfull
# Out:
# ['blue-collar',
#  'entrepreneur',
#  'technician',
#  'technician',
#  'blue-collar',
#  'blue-collar',
#  'housemaid',
#  'unknown',
#  'services',
#  'technician',
#  'management',
#  'services',
#  'blue-collar',
#  'housemaid',
#  'admin.',
#  'student',
#  'entrepreneur',
#  'blue-collar',
#  'blue-collar',
#  'entrepreneur',
#  'admin.',
#  'services',
#  'blue-collar',
#  'blue-collar',
#  'technician',
#  'admin.',
#  'technician',
#  'services',
#  'blue-collar',
#  'entrepreneur',
#  'services',
#  'unknown',
#  'services',
#  'management',
#  'housemaid',
#  'blue-collar',
#  'blue-collar',
#  'blue-collar',
#  'services',
#  'admin.',
#  'admin.',
#  'blue-collar',
#  'management',
#  'services',
#  'admin.',
#  'admin.',
#  'blue-collar',
#  'admin.',
#  'management',
#  'management',
#  'admin.',
#  'blue-collar',
#  'blue-collar',
#  'technician',
#  'technician',
#  'admin.',
#  'services',
#  'technician',
#  'admin.',
#  'services',
#  'entrepreneur',
#  'admin.',
# ...

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
stopwords = set(STOPWORDS)

# %%
job_yes_client_bankfull = ' '.join(yes_client_bankfull['job'].astype(str).tolist())
job_yes_client_bankfull_wc = WordCloud(background_color='white',
                                    stopwords=stopwords)

job_yes_client_bankfull_wc.generate(job_yes_client_bankfull)

# %%
fig = plt.figure()
fig.set_figwidth(8)
fig.set_figheight(12)

plt.imshow(job_yes_client_bankfull_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Dapat diketahui bahwa pekerjaan klien yang memutuskan untuk berlangganan kebanyakan adalah seorang admin.

# %% [markdown]
# # Kesimpulan

# %%
print("Berdasarkan Logistic Regression akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_logReg*100)
print("Berdasarkan K-Nearest Neighbors akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_knn*100)
print("Berdasarkan Support Vector Machine akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_svm*100)
print("Berdasarkan Decision Tree akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_decTree*100)
print("Berdasarkan Random Forest akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_ranForest*100)
print("Berdasarkan Naive Bayes akurasi prediksi klien yang akan berlangganan adalah sebesar : ", accuracy_naiveBayes*100)
# Out:
# Berdasarkan Logistic Regression akurasi prediksi klien yang akan berlangganan adalah sebesar :  91.18504128217582
# Berdasarkan K-Nearest Neighbors akurasi prediksi klien yang akan berlangganan adalah sebesar :  90.55366682855755
# Berdasarkan Support Vector Machine akurasi prediksi klien yang akan berlangganan adalah sebesar :  89.7887323943662
# Berdasarkan Decision Tree akurasi prediksi klien yang akan berlangganan adalah sebesar :  89.04808159300632
# Berdasarkan Random Forest akurasi prediksi klien yang akan berlangganan adalah sebesar :  91.68285575522098
# Berdasarkan Naive Bayes akurasi prediksi klien yang akan berlangganan adalah sebesar :  84.57989315201554

# %% [markdown]
# Dapat diketahui bahwa akurasi dengan menggunakan model Random Forest lebih tinggi yaitu sebesar 91.44001942690626

# %%
cm_decTree = confusion_matrix(y_test, decTree_prediction)
fig,ax = plt.subplots(figsize=(4,4))
plt.title("Decision Tree Logistic Regression")

ax.imshow(cm_decTree)
ax.grid(False)
ax.xaxis.set(ticks=(0,1),ticklabels = ('Prediksi 0s','Prediksi 1s'))
ax.yaxis.set(ticks=(0,1),ticklabels = ('Aktual 0s','Aktual 1s'))

for i in range(2):
    for j in range(2):
        ax.text(j,i,cm_decTree[i,j],ha='center',va='center',color='red')

plt.show()

# %% [markdown]
# Hal ini didukung juga oleh confusion matrix dari Decision Tree, dengan penjelasan sebagai berikut :
# * Terdapat 6826 data yang diprediksi tidak akan berlangganan dan ternyata memang benar tidak berlangganan (True Negative)
# * Terdapat 509 data yang diprediksi akan berlangganan dan ternyata memang benar berlangganan (True Positive)
